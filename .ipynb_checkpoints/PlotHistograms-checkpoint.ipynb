# %%
import mpltools
from mpltools import style
from mpltools import special
style.use( 'ggplot' )

import pandas
import csv
import os
import numpy as np
import json
from scipy.stats import gamma, norm


import numpy as np
import matplotlib.pyplot as pl 

% matplotlib inline

import mpltools
from mpltools import style
from mpltools import special
style.use( 'ggplot' )


path = "~/periodicmixture/PeriodicMixture/bin/Debug/"

# %%
def rose_diagram(ax, vals, ymax, label, N=24, 
                 xticks=['Midnight', '3am', '6am', '9am', 'Midday', '3pm', '6pm', '9pm'],
                 wrapped_normal=None,
                 wrapped_normal_mixture=None, 
                 scalingFunc = np.sqrt):
    """
    Rose diagram, used for plotting Histogram over 24 hours (or other count)
    Note that the area in a segment is proportional to the count, 
    so the radius is proportional to the square root of the count.
    """
    theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
    width = (2*np.pi) / N
    
    radii = scalingFunc(vals)
    ymax  = scalingFunc(ymax)
    
    bars = ax.bar(theta, radii, width=width)
    ax.set_xticklabels(xticks)
    dtheta = 360 / len(xticks)
    #ax[:set_thetagrids]([0:dtheta:360-dtheta])
    #ax[:set_thetagrids]([0:dtheta:(2:np.pi) - dtheta])
    ax.set_thetagrids(np.arange(0,360,dtheta))
    
    # Set y limit to the square root of the max, and set the tick labels to be 
    # the values squared. Also only show every third tick label
    ax.set_ylim(0,(ymax))
    ticks = ax.get_yticks()[::2]
    ax.set_yticks(ticks)
    ax.set_yticklabels([int(t) for t in np.power(ticks,2)])
    ax.set_theta_zero_location('N')
    ax.set_theta_direction(-1)
    
    ret = None
    
    if wrapped_normal is not None:
        rng = np.linspace(0, wrapped_normal._period, 100, endpoint=True)
        pdf = wrapped_normal.pdf(rng)
        pdfs = pdf / max(pdf) * (ymax)
        ax.plot(rng / wrapped_normal._period * 2 * np.pi, pdfs, 'r', linewidth=2)
        label += "\n" + str(wrapped_normal)
        
        ret = pdfs
    
    if wrapped_normal_mixture is not None:
        rng = np.linspace(0, wrapped_normal_mixture._period, 100, endpoint=True)
        mixtureSums = []
        for wn in wrapped_normal_mixture._wrapped_normals:
            pdf = np.maximum(0, wn.pdf(rng))
            pdfs = pdf / max(pdf) * np.sqrt(wn._weight) * (ymax)
            
            mixtureSums.append( np.asarray( pdfs ) )
            label += "\n" + str(wn)
        
        mixtureSum = np.asarray( mixtureSums ).sum( 0 )
        
        for mm in mixtureSums:
            ax.plot(rng / wn._period * 2 * np.pi, mm / mixtureSum.max(), 'r', linewidth=1)
        
        ax.plot(rng / wn._period * 2 * np.pi, mixtureSum / mixtureSum.max(), 'k', linewidth=2)
        label += "\n"
        
        ret = mixtureSum 
        
            
    ax.set_title(label, y=1.08)
    
    return ret

# %%
class WrappedNormal(object):
    def __init__(self, mean, variance, period=2*np.pi, weight=1.0):
        self._mean = mean
        self._variance = variance
        self._period = period
        self._weight = weight
        
    def __repr__(self):
        return 'WrappedNormal(mean={0}, variance={1}, period={2})'.format(self._mean, self._variance, self._period)
        
    def __str__(self):
        label = 'WN({0:.2f},{1:.2f},{2:0.1f}'.format(self._mean, self._variance, self._period)
        if self._weight != 1.0:
            label = label + ',{0:0.1f}'.format(self._weight)
        return label + ')'
    
    def pdf(self, x, verbose=False):
            # p(x) = sum_k N(x + L*k; m, v)
            #      = a/(2*pi) + a/pi sum_{k=1}^inf cos(a*k*(x-m)) exp(-(a*k)^2 v/2) where a = 2*pi/L
            if self._variance < 0.15 * pow(self._period / 2 / np.pi, 2):
                # use Gaussian summation formula
                if verbose:
                    print('Using Gaussian summation formula')
                result = 0 #-np.infty;
                for k in xrange(-1,1):
                    # logp = Gaussian.GetLogProb(value + k*Period)
                    # result = MMath.LogSumExp(result, logp)
                    tmp = norm.pdf(x + k*self._period, self._mean, self._variance)
                    #print(tmp.min(), tmp.max())
                    result += tmp
                return result
            else:
                if verbose:
                    print('Using cosine formula')
                # v >= 0.15
                # use the cosine formula
                result = 0.5
                aOverPi = 2.0 / self._period
                a = aOverPi * np.pi
                diff = x - self._mean
                vHalf = self._variance * 0.5
                for k in xrange(1,8):
                    ak = a*k
                    result += np.cos(ak*diff) * np.exp(-ak*ak*vHalf)
                #print(result, aOverPi, self._period)
                return result * aOverPi

class WrappedNormalMixture(object):
    def __init__(self, wrapped_normals, weights):
        self._period = wrapped_normals[0]._period
        for wn in wrapped_normals[1:]:
            if wn._period != self._period:
                # BOMB OUT HERE
                raise error('Periods must be the same')
        self._wrapped_normals = wrapped_normals
        for (weight, wn) in zip(weights, self._wrapped_normals):
            wn._weight = weight
        self._weights = weights

# %%
bins = np.linspace( 0, 24, 25 )
scalingFunc = lambda xx: np.sqrt( xx )


dataParams = json.load( open( path + "/test.json", "r" ) )
print dataParams
items = dataParams["Params"]
data = np.asarray( dataParams["Data"] )



for ii in np.arange( len( items ) ): 
    while items[ii]["Mean"] < 0:
        items[ii]["Mean"] += 24
        
    while items[ii]["Mean"] > 24: 
        items[ii]["Mean"] -= 24
        
    print (   "Mean:     {Mean}" + 
            "\nVariance: {Variance} (Precision: {Precision})" + 
            "\nWeight:   {Weight}\n" ).format( **items[ii] )

    
hist = np.histogram( data, bins = bins )
hist = np.asarray( hist[0], dtype = np.float )
hist /= hist.max()

wns = []
weights = []

for item in items:
    weights.append( item['Weight'] )
    wns.append( WrappedNormal( item['Mean'], item['Variance'], item['Period'] ) )
    
pl.figure()
ax = pl.gca( polar = True )
wnm = WrappedNormalMixture( wns, weights )
likelihood = rose_diagram( ax, hist, hist.max(), "ads", wrapped_normal_mixture = wnm, scalingFunc=scalingFunc )


pl.figure()
a = pl.hist( data, bins = bins );
pl.plot( np.linspace( 0, 24, len( likelihood ) ), a[0].max() * likelihood / likelihood.max(), 'k', linewidth=2 )
pl.xlim( ( 0, 24 ) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-8b1e1647c34d> in <module>()
#       5 dataParams = json.load( open( path + "/test.json", "r" ) )
#       6 print dataParams
# ----> 7 items = dataParams["Params"]
#       8 data = np.asarray( dataParams["Data"] )
#       9
#
# TypeError: list indices must be integers, not str
# [19.737426393558422, 22.006554303163387, 23.023456215078294, 1.998378770251399, 2.894564383217384, 0.6219818206005288, 23.216455958705023, 1.9659698117610191, 0.24821404586327134, 4.95059850136556, 2.206971300723213, 16.968872965591686, 21.46665240870606, 18.200373707795507, 23.10954113968663, 1.0769977346882404, 3.031012914506827, 21.47905422150336, 21.0350959606277, 7.981169077408335, 0.06860148910772912, 4.776016322972003, 23.776832804490788, 19.26928356368395, 1.9076835215486447, 1.74369966912534, 3.8275828894966994, 23.80556263097899, 22.643775559783354, 22.61467783166348, 2.695168417558528, 3.968281359680569, 3.871879976923102, 23.876014105728665, 20.92706567332063, 23.954332341834156, 3.8588944817861943, 23.14475869469564, 19.379123942189324, 23.887063190845236, 1.0125869344337963, 6.569291768742303, 3.4242211099075135, 0.8309552657085923, 0.8967576490916613, 3.9830095840092445, 23.473828133798186, 1.3312037413329205, 23.215182761840275, 21.44047736533802, 4.918086332804503, 5.3295716815671845, 21.24137215730362, 21.541891001135795, 19.819023481638368, 3.745097516827198, 0.9534277099492647, 1.197931994159045, 3.2024027956651233, 2.8127575799862012, 19.664905460021487, 22.74813069179127, 18.443475969801113, 0.8974867465982683, 6.392276408137047, 6.7051642066096395, 18.143549380054992, 21.033271709212194, 1.9571150762177802, 2.1970718556148188, 1.0169405777227039, 0.052533152205967326, 18.782639858279232, 1.8358143374309606, 23.770571705929473, 19.480279295448444, 1.493430534563816, 1.2178779316425432, 17.554118054606874, 2.1890613964481602, 22.102802195017816, 19.65731081627223, 4.5581915116959735, 23.75759590881948, 23.57143443383499, 1.1644698148632409, 20.23657464934364, 2.2115422580310393, 0.7621898727363323, 7.546379060199123, 22.51226106541996, 22.106560176918936, 0.9641714491381785, 4.689175945991842, 20.84221126133752, 2.805479833463389, 20.73643864604753, 21.830253149736084, 22.439312522561806, 22.610241238764125, 3.6571474362152507, 0.06329526313568579, 2.8011504392461988, 0.02907698019537719, 5.681490427138623, 2.718985596243665, 20.487527555950667, 0.5996455479181932, 3.1917082760622564, 20.53307130894087, 23.949229419092525, 23.704459578268274, 4.178327387267294, 4.944432009386733, 4.204448254740656, 23.105389593154417, 2.4861988234173515, 0.44714896134467264, 23.141417693406236, 23.02087694508718, 0.2743991233954204, 1.7231840238195062, 19.450517816880094, 1.1960829910691686, 23.320775957578977, 0.8757976773581109, 2.8354248873717203, 22.148092088899535, 23.546819571091344, 1.073278358438614, 23.686363884182818, 18.747503887061388, 2.218472898957465, 22.651393928981957, 22.540543668047707, 1.0396097269894515, 21.181710788217273, 1.5021088573309842, 21.026355242119564, 1.094360526225119, 4.802947392592991, 21.267110888216216, 23.940448801513945, 5.212979158719953, 20.55588298702735, 21.609692380036964, 6.3541305963636265, 22.94184885741201, 22.32896707633688, 1.2743885375325377, 20.11371965915422, 23.86376833927575, 5.828354741134614, 23.725260282902333, 19.86115671292808, 4.1642793491786865, 20.457106631316897, 4.094544976329967, 20.160974380330803, 17.2485096277153, 3.95208058283038, 23.930027421894582, 23.59498425603303, 3.646278686911442, 3.9005693455968578, 3.691718469088756, 2.392966523383879, 1.9395039132922207, 22.421183929222828, 18.806494480984146, 1.8588176896224908, 23.46876722385213, 23.564398742602556, 0.42177881448784404, 4.478902041898802, 23.7829969985759, 1.8012839808351733, 23.36907404720823, 0.5211051024842668, 20.548116001831474, 23.864936657506103, 8.854230609309038, 6.0269376741804175, 21.97152574521697, 21.697722880678928, 22.937232698722646, 4.788115909267394, 21.840147909016114, 23.66816799443647, 21.292231452665604, 20.710280963503063, 20.71960249985436, 18.999011483755282, 3.0162205773207607, 22.570436139086084, 2.228465681281019, 3.9860104161140137, 5.516608191789331, 0.7283964894148873, 0.09857418876991275, 3.319666628656015, 22.387885029375084, 20.642106991657887, 19.8201140397 ...
